# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import pandas as pd

torch.manual_seed(27)
device = torch.device("cpu")

# %%
transform = transforms.Compose([transforms.ToTensor(),transforms.Normalize((0.1307,), (0.3081,))])
train_data = datasets.MNIST('mnist_data', train=True, download=True, transform=transform)
test_data = datasets.MNIST('mnist_data', train=False, download=True, transform=transform)

training_DataLoader = torch.utils.data.DataLoader(train_data, batch_size=64, shuffle=True)
testing_DataLoader = torch.utils.data.DataLoader(test_data, batch_size=64, shuffle=True)

# %%
class DNNModel(nn.Module):
    def __init__(self):
        super(DNNModel, self).__init__()
        self.Dense1 = nn.Linear(28*28, 64)
        self.Dense2 = nn.Linear(64, 32)
        self.Dense3 = nn.Linear(32, 10)

    def forward(self, inputData):
        inputData = inputData.view(inputData.shape[0], -1)
        inputData = F.relu(self.Dense1(inputData))
        inputData = F.relu(self.Dense2(inputData))
        inputData = self.Dense3(inputData)
        return inputData

# %%
def train(model, optimizer, train_loader):
    model.train()
    train_loss = []
    train_acc = []
    collected_weights_layer1 = []
    collected_weights_whole = []
    loss_func = torch.nn.CrossEntropyLoss()

    for epoch in range(1, 25):
        correct = 0
        total_samples = 0
        epoch_loss = 0

        for i, (images, labels) in enumerate(train_loader):
            output = model(images)
            loss = loss_func(output, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            predicted = output.argmax(dim=1)
            correct += (predicted == labels).sum().item()
            total_samples += labels.size(0)

            epoch_loss += loss.item()

        avg_loss = epoch_loss / len(train_loader)
        avg_acc = correct / total_samples

        if epoch % 3 == 0:
            with torch.no_grad():
                layer1_weights = []
                whole_weights = []
                for name, param in model.named_parameters():
                    if 'weight' in name:
                        whole_weights.append(param.detach().numpy().ravel())
                        if 'Dense1' in name:
                            layer1_weights.append(param.detach().numpy().ravel())
                collected_weights_layer1.append(np.concatenate(layer1_weights))
                collected_weights_whole.append(np.concatenate(whole_weights))

        train_loss.append(avg_loss)
        train_acc.append(avg_acc)
        print(f'Epoch {epoch}, Loss: {avg_loss:.4f}, Accuracy: {avg_acc * 100:.2f}%')

    return train_loss, train_acc, collected_weights_layer1, collected_weights_whole

# %%
def apply_pca(weights):
    weights_matrix = np.array(weights)
    print(weights_matrix.shape)
    pca = PCA(n_components=2)
    pca_result = pca.fit_transform(weights_matrix)
    return pca_result

# %%
layer_1_pca = []
whole_pca = []
train_acc_arr = []
train_loss_arr = []

for trainingIndex in range(1,9):
    model = DNNModel().to(device)
    optimizer1 = optim.Adam(model.parameters(), lr=1e-4)
    train_loss, train_acc, layer1_weights, whole_weights = train(model, optimizer1, training_DataLoader)

    pca_out_layer1 = apply_pca(layer1_weights)
    pca_out_whole = apply_pca(whole_weights)
    
    layer_1_pca.append(pca_out_layer1)
    whole_pca.append(pca_out_whole)
    train_loss_arr.append(train_loss)
    train_acc_arr.append(train_acc)
# Out:
# Epoch 1, Loss: 0.7943, Accuracy: 80.06%
# Epoch 2, Loss: 0.3304, Accuracy: 90.57%
# Epoch 3, Loss: 0.2757, Accuracy: 92.01%
# Epoch 4, Loss: 0.2424, Accuracy: 93.01%
# Epoch 5, Loss: 0.2174, Accuracy: 93.76%
# Epoch 6, Loss: 0.1975, Accuracy: 94.46%
# Epoch 7, Loss: 0.1812, Accuracy: 94.83%
# Epoch 8, Loss: 0.1675, Accuracy: 95.18%
# Epoch 9, Loss: 0.1558, Accuracy: 95.51%
# Epoch 9, Loss: 0.1504, Accuracy: 95.68%
# Epoch 10, Loss: 0.1397, Accuracy: 96.01%
# Epoch 11, Loss: 0.1304, Accuracy: 96.26%
# Epoch 12, Loss: 0.1220, Accuracy: 96.53%
# Epoch 13, Loss: 0.1147, Accuracy: 96.70%
# Epoch 14, Loss: 0.1079, Accuracy: 96.83%
# Epoch 15, Loss: 0.1021, Accuracy: 97.04%
# Epoch 16, Loss: 0.0967, Accuracy: 97.27%
# Epoch 17, Loss: 0.0917, Accuracy: 97.36%
# Epoch 18, Loss: 0.0870, Accuracy: 97.54%
# Epoch 19, Loss: 0.0832, Accuracy: 97.59%
# Epoch 20, Loss: 0.0794, Accuracy: 97.72%
# Epoch 21, Loss: 0.0759, Accuracy: 97.84%
# Epoch 22, Loss: 0.0724, Accuracy: 97.94%
# Epoch 23, Loss: 0.0694, Accuracy: 98.03%
# Epoch 24, Loss: 0.0664, Accuracy: 98.17%
# (8, 50176)
# (8, 52544)
# Epoch 1, Loss: 0.8267, Accuracy: 78.42%
# Epoch 2, Loss: 0.3286, Accuracy: 90.70%
# Epoch 3, Loss: 0.2706, Accuracy: 92.24%
# Epoch 4, Loss: 0.2370, Accuracy: 93.15%
# Epoch 5, Loss: 0.2131, Accuracy: 93.87%
# Epoch 6, Loss: 0.1937, Accuracy: 94.41%
# Epoch 7, Loss: 0.1779, Accuracy: 94.82%
# Epoch 8, Loss: 0.1641, Accuracy: 95.27%
# Epoch 9, Loss: 0.1518, Accuracy: 95.56%
# Epoch 10, Loss: 0.1413, Accuracy: 95.91%
# Epoch 11, Loss: 0.1315, Accuracy: 96.18%
# Epoch 12, Loss: 0.1224, Accuracy: 96.45%
# Epoch 13, Loss: 0.1146, Accuracy: 96.63%
# Epoch 14, Loss: 0.1077, Accuracy: 96.84%
# Epoch 15, Loss: 0.1013, Accuracy: 97.05%
# Epoch 16, Loss: 0.0958, Accuracy: 97.23%
# Epoch 17, Loss: 0.0907, Accuracy: 97.38%
# Epoch 18, Loss: 0.0865, Accuracy: 97.53%
# Epoch 19, Loss: 0.0819, Accuracy: 97.66%
# Epoch 20, Loss: 0.0781, Accuracy: 97.75%
# Epoch 21, Loss: 0.0743, Accuracy: 97.91%
# Epoch 22, Loss: 0.0711, Accuracy: 97.92%
# Epoch 23, Loss: 0.0682, Accuracy: 98.08%
# Epoch 24, Loss: 0.0649, Accuracy: 98.14%
# (8, 50176)
# (8, 52544)
# Epoch 1, Loss: 0.7896, Accuracy: 80.23%
# Epoch 2, Loss: 0.3310, Accuracy: 90.61%
# Epoch 3, Loss: 0.2775, Accuracy: 92.00%
# Epoch 4, Loss: 0.2454, Accuracy: 92.87%
# Epoch 5, Loss: 0.2205, Accuracy: 93.63%
# Epoch 6, Loss: 0.2005, Accuracy: 94.23%
# Epoch 7, Loss: 0.1844, Accuracy: 94.68%
# Epoch 8, Loss: 0.1707, Accuracy: 95.09%
# Epoch 9, Loss: 0.1595, Accuracy: 95.36%
# Epoch 10, Loss: 0.1495, Accuracy: 95.68%
# Epoch 11, Loss: 0.1402, Accuracy: 95.94%
# Epoch 12, Loss: 0.1318, Accuracy: 96.15%
# Epoch 13, Loss: 0.1246, Accuracy: 96.38%
# Epoch 14, Loss: 0.1177, Accuracy: 96.60%
# Epoch 15, Loss: 0.1113, Accuracy: 96.75%
# Epoch 16, Loss: 0.1053, Accuracy: 96.94%
# Epoch 17, Loss: 0.1002, Accuracy: 97.06%
# Epoch 18, Loss: 0.0952, Accuracy: 97.27%
# Epoch 19, Loss: 0.0908, Accuracy: 97.38%
# Epoch 20, Loss: 0.0863, Accuracy: 97.48%
# Epoch 21, Loss: 0.0823, Accuracy: 97.68%
# Epoch 22, Loss: 0.0787, Accuracy: 97.73%
# Epoch 23, Loss: 0.0753, Accuracy: 97.84%
# Epoch 24, Loss: 0.0722, Accuracy: 97.90%
# (8, 50176)
# (8, 52544)
# Epoch 1, Loss: 0.8289, Accuracy: 78.22%
# Epoch 2, Loss: 0.3280, Accuracy: 90.64%
# Epoch 3, Loss: 0.2767, Accuracy: 91.94%
# Epoch 4, Loss: 0.2465, Accuracy: 92.83%
# Epoch 5, Loss: 0.2232, Accuracy: 93.54%
# Epoch 6, Loss: 0.2043, Accuracy: 94.08%
# Epoch 7, Loss: 0.1872, Accuracy: 94.56%
# Epoch 8, Loss: 0.1728, Accuracy: 95.00%
# Epoch 9, Loss: 0.1601, Accuracy: 95.39%
# Epoch 10, Loss: 0.1496, Accuracy: 95.62%
# Epoch 11, Loss: 0.1400, Accuracy: 95.87%
# Epoch 12, Loss: 0.1312, Accuracy: 96.22%
# Epoch 13, Loss: 0.1237, Accuracy: 96.44%
# Epoch 14, Loss: 0.1169, Accuracy: 96.60%
# Epoch 15, Loss: 0.1101, Accuracy: 96.82%
# Epoch 16, Loss: 0.1043, Accuracy: 97.01%
# Epoch 17, Loss: 0.0990, Accuracy: 97.13%
# Epoch 18, Loss: 0.0934, Accuracy: 97.32%
# Epoch 19, Loss: 0.0892, Accuracy: 97.40%
# Epoch 20, Loss: 0.0851, Accuracy: 97.58%
# Epoch 21, Loss: 0.0813, Accuracy: 97.67%
# Epoch 22, Loss: 0.0774, Accuracy: 97.76%
# Epoch 23, Loss: 0.0742, Accuracy: 97.86%
# Epoch 24, Loss: 0.0709, Accuracy: 97.93%
# (8, 50176)
# (8, 52544)

# %%
plt.figure(figsize=(10, 10))
plt.xlabel('Weight PC1')
plt.ylabel('Weight PC2')
plt.title('Layer 1')
for i in range(len(layer_1_pca)):
    W_i = layer_1_pca[i]
    plt.scatter(W_i[:, 0], W_i[:, 1])

plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.xlabel('Weight PC1')
plt.ylabel('Weight PC2')
plt.title('Layer 1')
for i in range(len(whole_pca)):
    W_i = whole_pca[i]
    plt.scatter(W_i[:, 0], W_i[:, 1])

plt.show()
