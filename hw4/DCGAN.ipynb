# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torch.utils.data import Subset
import matplotlib.pyplot as plt
import numpy as np
import torchvision.utils as utils
from IPython.display import HTML
import time
from torchvision import models
import torch.nn.functional as F
from scipy import linalg

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
batch_size = 32

dataset = datasets.CIFAR10(root="data", download=True, transform=transforms.Compose([transforms.Resize(64), transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),]))
dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True)
# Out:
# Files already downloaded and verified

# %%
class Generator(nn.Module):
    def __init__(self, channels_noise, channels_img, features_g):
        super(Generator, self).__init__()
        self.net = nn.Sequential(
            self.Gnet(channels_noise, features_g * 16, 4, 1, 0),
            self.Gnet(features_g * 16, features_g * 8, 4, 2, 1),
            self.Gnet(features_g * 8, features_g * 4, 4, 2, 1),
            self.Gnet(features_g * 4, features_g * 2, 4, 2, 1),
            nn.ConvTranspose2d(
                features_g * 2, channels_img, kernel_size=4, stride=2, padding=1
            ),
            nn.Tanh(),
        )

    def Gnet(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.ConvTranspose2d(
                in_channels,
                out_channels,
                kernel_size,
                stride,
                padding,
                bias=False,
            ),
            nn.BatchNorm2d(out_channels,momentum=0.9),
            nn.ReLU(),
        )

    def forward(self, x):
        return self.net(x)

class Discriminator(nn.Module):
    def __init__(self, channels_img, features_d):
        super(Discriminator, self).__init__()
        self.disc = nn.Sequential(
            nn.Conv2d(
                channels_img, features_d, kernel_size=4, stride=2, padding=1
            ),
            nn.LeakyReLU(0.2),
            self.Dnet(features_d, features_d * 2, 4, 2, 1),
            self.Dnet(features_d * 2, features_d * 4, 4, 2, 1),
            self.Dnet(features_d * 4, features_d * 8, 4, 2, 1),
            nn.Conv2d(features_d * 8, 1, kernel_size=4, stride=2, padding=0),
            nn.Sigmoid(),
        )

    def Dnet(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.Conv2d(
                in_channels,
                out_channels,
                kernel_size,
                stride,
                padding,
                bias=False,
            ),
            nn.LeakyReLU(0.2),
        )

    def forward(self, x):
        return self.disc(x)

# %%
def initialize_weights(model):
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.ConvTranspose2d, nn.BatchNorm2d)):
            nn.init.normal_(m.weight.data, 0.0, 0.02)

# %%
gen = Generator(channels_noise = 100, channels_img = 3, features_g = 64).to(device)
disc = Discriminator(channels_img = 3, features_d = 64).to(device)
initialize_weights(gen)
initialize_weights(disc)
lr = 2e-4

# %%
optimGenerator = optim.Adam(gen.parameters(), lr=lr, betas=(0.5, 0.999))
optimDiscriminator = optim.Adam(disc.parameters(), lr=lr, betas=(0.5, 0.999))
criterion = nn.BCELoss()
fixed_noise = torch.randn(32, 100, 1, 1).to(device)
step = 0

# %%
class InceptionV3(nn.Module):
    """Pretrained InceptionV3 network returning feature maps"""
    DEFAULT_BLOCK_INDEX = 3

    BLOCK_INDEX_BY_DIM = {
        64: 0,
        192: 1,
        768: 2,
        2048: 3
    }

    def __init__(self,
                 output_blocks=[DEFAULT_BLOCK_INDEX],
                 resize_input=True,
                 normalize_input=True,
                 requires_grad=False):
        
        super(InceptionV3, self).__init__()

        self.resize_input = resize_input
        self.normalize_input = normalize_input
        self.output_blocks = sorted(output_blocks)
        self.last_needed_block = max(output_blocks)

        assert self.last_needed_block <= 3, \
            'Last possible output block index is 3'

        self.blocks = nn.ModuleList()

        
        inception = models.inception_v3(pretrained=True)

        block0 = [
            inception.Conv2d_1a_3x3,
            inception.Conv2d_2a_3x3,
            inception.Conv2d_2b_3x3,
            nn.MaxPool2d(kernel_size=3, stride=2)
        ]
        self.blocks.append(nn.Sequential(*block0))

        if self.last_needed_block >= 1:
            block1 = [
                inception.Conv2d_3b_1x1,
                inception.Conv2d_4a_3x3,
                nn.MaxPool2d(kernel_size=3, stride=2)
            ]
            self.blocks.append(nn.Sequential(*block1))

        if self.last_needed_block >= 2:
            block2 = [
                inception.Mixed_5b,
                inception.Mixed_5c,
                inception.Mixed_5d,
                inception.Mixed_6a,
                inception.Mixed_6b,
                inception.Mixed_6c,
                inception.Mixed_6d,
                inception.Mixed_6e,
            ]
            self.blocks.append(nn.Sequential(*block2))

        if self.last_needed_block >= 3:
            block3 = [
                inception.Mixed_7a,
                inception.Mixed_7b,
                inception.Mixed_7c,
                nn.AdaptiveAvgPool2d(output_size=(1, 1))
            ]
            self.blocks.append(nn.Sequential(*block3))

        for param in self.parameters():
            param.requires_grad = requires_grad

    def forward(self, inp):
        outp = []
        x = inp

        if self.resize_input:
            x = F.interpolate(x,
                              size=(299, 299),
                              mode='bilinear',
                              align_corners=False)

        if self.normalize_input:
            x = 2 * x - 1

        for idx, block in enumerate(self.blocks):
            x = block(x)
            if idx in self.output_blocks:
                outp.append(x)

            if idx == self.last_needed_block:
                break

        return outp
    
block_idx = InceptionV3.BLOCK_INDEX_BY_DIM[2048]
model = InceptionV3([block_idx])
model=model.cuda()
# Out:
# /home/usiriko/.local/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/usiriko/.local/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/inception_v3_google-0cc3c7bd.pth" to /home/usiriko/.cache/torch/hub/checkpoints/inception_v3_google-0cc3c7bd.pth
# 100%|██████████| 104M/104M [00:00<00:00, 139MB/s]

# %%
def calculate_activation_statistics(images, model, batch_size=128, dims=2048, cuda=False):
    model.eval()
    act=np.empty((len(images), dims))
    
    if cuda:
        batch=images.cuda()
    else:
        batch=images
    pred = model(batch)[0]
    if pred.size(2) != 1 or pred.size(3) != 1:
        pred = adaptive_avg_pool2d(pred, output_size=(1, 1))

    act= pred.cpu().data.numpy().reshape(pred.size(0), -1)
    
    mu = np.mean(act, axis=0)
    sigma = np.cov(act, rowvar=False)
    return mu, sigma

def calculate_frechet_distance(mu1, sigma1, mu2, sigma2, eps=1e-6):
    mu1 = np.atleast_1d(mu1)
    mu2 = np.atleast_1d(mu2)

    sigma1 = np.atleast_2d(sigma1)
    sigma2 = np.atleast_2d(sigma2)

    assert mu1.shape == mu2.shape, \
        'Training and test mean vectors have different lengths'
    assert sigma1.shape == sigma2.shape, \
        'Training and test covariances have different dimensions'

    diff = mu1 - mu2

    
    covmean, _ = linalg.sqrtm(sigma1.dot(sigma2), disp=False)
    if not np.isfinite(covmean).all():
        msg = ('fid calculation produces singular product; '
               'adding %s to diagonal of cov estimates') % eps
        print(msg)
        offset = np.eye(sigma1.shape[0]) * eps
        covmean = linalg.sqrtm((sigma1 + offset).dot(sigma2 + offset))

    
    if np.iscomplexobj(covmean):
        if not np.allclose(np.diagonal(covmean).imag, 0, atol=1e-3):
            m = np.max(np.abs(covmean.imag))
            raise ValueError('Imaginary component {}'.format(m))
        covmean = covmean.real

    tr_covmean = np.trace(covmean)

    return (diff.dot(diff) + np.trace(sigma1) +
            np.trace(sigma2) - 2 * tr_covmean)

def calculate_fretchet(images_real,images_fake,model):
    mu_1,std_1 = calculate_activation_statistics(images_real,model,cuda=True)
    mu_2,std_2 = calculate_activation_statistics(images_fake,model,cuda=True)
    fid_value = calculate_frechet_distance(mu_1, std_1, mu_2, std_2)
    return fid_value

# %%
gen.train()
disc.train()
# Out:
# Discriminator(
#   (disc): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (3): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (4): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): LeakyReLU(negative_slope=0.2)
#     )
#     (5): Conv2d(512, 1, kernel_size=(4, 4), stride=(2, 2))
#     (6): Sigmoid()
#   )
# )

# %%
GenLoss = []
DiscLoss = []
img_list = []
fretchet_distances = []
iters = 0

num_epochs = 20
for epoch in range(num_epochs):
    epoch = epoch+1

    for batch_idx, data in enumerate(dataloader,0):
        real = data[0].to(device)
        noise = torch.randn(128, 100, 1, 1).to(device)
        fake = gen(noise)

        disc_real = disc(real).reshape(-1)
        loss_disc_real = criterion(disc_real, torch.ones_like(disc_real))
        disc_fake = disc(fake.detach()).reshape(-1)
        loss_disc_fake = criterion(disc_fake, torch.zeros_like(disc_fake))
        loss_disc = (loss_disc_real + loss_disc_fake) / 2
        disc.zero_grad()
        loss_disc.backward()
        optimDiscriminator.step()

        output = disc(fake).reshape(-1)
        loss_gen = criterion(output, torch.ones_like(output))
        gen.zero_grad()
        loss_gen.backward()
        optimGenerator.step()

        if batch_idx % 100 == 0:
            print(
                f"Epoch [{epoch}/{num_epochs}] Batch {batch_idx}/{len(dataloader)} \
                  Loss Discriminator: {loss_disc:.3f}, loss Generator: {loss_gen:.3f}"
            )
        GenLoss.append(loss_gen.detach().cpu())
        DiscLoss.append(loss_disc.detach().cpu())
        
        if (iters % 500 == 0) or ((epoch == num_epochs) and (batch_idx == len(dataloader)-1)):
            with torch.no_grad():
                fake = gen(fixed_noise).detach().cpu()
            img_list.append(utils.make_grid(fake, padding=2, normalize=True))
            
        iters += 1
    fretchet_dist = calculate_fretchet(real, fake, model)
    print('Fretchet Distance: ', fretchet_dist)
    fretchet_distances.append(fretchet_dist)
# Out:
# !!Training Started!!
# Epoch [1/50] Batch 0/1563                   Loss Discriminator: 0.694, loss Generator: 0.691
# Epoch [1/50] Batch 100/1563                   Loss Discriminator: 0.300, loss Generator: 2.069
# Epoch [1/50] Batch 200/1563                   Loss Discriminator: 0.199, loss Generator: 2.541
# Epoch [1/50] Batch 300/1563                   Loss Discriminator: 0.438, loss Generator: 1.981
# Epoch [1/50] Batch 400/1563                   Loss Discriminator: 0.444, loss Generator: 1.457
# Epoch [1/50] Batch 500/1563                   Loss Discriminator: 0.504, loss Generator: 1.535
# Epoch [1/50] Batch 600/1563                   Loss Discriminator: 0.439, loss Generator: 1.722
# Epoch [1/50] Batch 700/1563                   Loss Discriminator: 0.624, loss Generator: 1.541
# Epoch [1/50] Batch 800/1563                   Loss Discriminator: 0.487, loss Generator: 1.462
# Epoch [1/50] Batch 900/1563                   Loss Discriminator: 0.577, loss Generator: 1.118
# Epoch [1/50] Batch 1000/1563                   Loss Discriminator: 0.623, loss Generator: 1.102
# Epoch [1/50] Batch 1100/1563                   Loss Discriminator: 0.588, loss Generator: 0.939
# Epoch [1/50] Batch 1200/1563                   Loss Discriminator: 0.626, loss Generator: 0.940
# Epoch [1/50] Batch 1300/1563                   Loss Discriminator: 0.636, loss Generator: 1.266
# Epoch [1/50] Batch 1400/1563                   Loss Discriminator: 0.580, loss Generator: 0.963
# Epoch [1/50] Batch 1500/1563                   Loss Discriminator: 0.626, loss Generator: 0.939
# Fretchet Distance:  374.8259526003323
# Epoch [2/50] Batch 0/1563                   Loss Discriminator: 0.619, loss Generator: 0.920
# Epoch [2/50] Batch 100/1563                   Loss Discriminator: 0.640, loss Generator: 1.068
# Epoch [2/50] Batch 200/1563                   Loss Discriminator: 0.672, loss Generator: 0.953
# Epoch [2/50] Batch 300/1563                   Loss Discriminator: 0.592, loss Generator: 1.082
# Epoch [2/50] Batch 400/1563                   Loss Discriminator: 0.660, loss Generator: 0.858
# Epoch [2/50] Batch 500/1563                   Loss Discriminator: 0.590, loss Generator: 1.068
# Epoch [2/50] Batch 600/1563                   Loss Discriminator: 0.629, loss Generator: 1.009
# Epoch [2/50] Batch 700/1563                   Loss Discriminator: 0.640, loss Generator: 1.184
# Epoch [2/50] Batch 800/1563                   Loss Discriminator: 0.504, loss Generator: 1.443
# Epoch [2/50] Batch 900/1563                   Loss Discriminator: 0.587, loss Generator: 1.230
# Epoch [2/50] Batch 1000/1563                   Loss Discriminator: 0.740, loss Generator: 0.925
# Epoch [2/50] Batch 1100/1563                   Loss Discriminator: 0.598, loss Generator: 1.097
# Epoch [2/50] Batch 1200/1563                   Loss Discriminator: 0.758, loss Generator: 0.990
# Epoch [2/50] Batch 1300/1563                   Loss Discriminator: 0.674, loss Generator: 0.764
# Epoch [2/50] Batch 1400/1563                   Loss Discriminator: 0.712, loss Generator: 1.050
# Epoch [2/50] Batch 1500/1563                   Loss Discriminator: 0.574, loss Generator: 0.947
# Fretchet Distance:  278.25278242467994
# Epoch [3/50] Batch 0/1563                   Loss Discriminator: 0.686, loss Generator: 1.006
# Epoch [3/50] Batch 100/1563                   Loss Discriminator: 0.681, loss Generator: 0.921
# Epoch [3/50] Batch 200/1563                   Loss Discriminator: 0.616, loss Generator: 0.898
# Epoch [3/50] Batch 300/1563                   Loss Discriminator: 0.594, loss Generator: 1.086
# Epoch [3/50] Batch 400/1563                   Loss Discriminator: 0.563, loss Generator: 1.305
# Epoch [3/50] Batch 500/1563                   Loss Discriminator: 0.674, loss Generator: 1.524
# Epoch [3/50] Batch 600/1563                   Loss Discriminator: 0.633, loss Generator: 0.937
# Epoch [3/50] Batch 700/1563                   Loss Discriminator: 0.668, loss Generator: 0.998
# Epoch [3/50] Batch 800/1563                   Loss Discriminator: 0.678, loss Generator: 0.962
# Epoch [3/50] Batch 900/1563                   Loss Discriminator: 0.628, loss Generator: 0.845
# Epoch [3/50] Batch 1000/1563                   Loss Discriminator: 0.627, loss Generator: 0.722
# Epoch [3/50] Batch 1100/1563                   Loss Discriminator: 0.653, loss Generator: 0.850
# Epoch [3/50] Batch 1200/1563                   Loss Discriminator: 0.679, loss Generator: 0.749
# Epoch [3/50] Batch 1300/1563                   Loss Discriminator: 0.623, loss Generator: 0.814
# Epoch [3/50] Batch 1400/1563                   Loss Discriminator: 0.693, loss Generator: 0.752
# Epoch [3/50] Batch 1500/1563                   Loss Discriminator: 0.670, loss Generator: 1.096
# Fretchet Distance:  264.16799371339494
# Epoch [4/50] Batch 0/1563                   Loss Discriminator: 0.695, loss Generator: 0.926
# Epoch [4/50] Batch 100/1563                   Loss Discriminator: 0.646, loss Generator: 0.772
# Epoch [4/50] Batch 200/1563                   Loss Discriminator: 0.599, loss Generator: 0.870
# Epoch [4/50] Batch 300/1563                   Loss Discriminator: 0.685, loss Generator: 0.802
# Epoch [4/50] Batch 400/1563                   Loss Discriminator: 0.652, loss Generator: 1.009
# Epoch [4/50] Batch 500/1563                   Loss Discriminator: 0.763, loss Generator: 0.841
# Epoch [4/50] Batch 600/1563                   Loss Discriminator: 0.631, loss Generator: 0.866
# Epoch [4/50] Batch 700/1563                   Loss Discriminator: 0.602, loss Generator: 0.728
# Epoch [4/50] Batch 800/1563                   Loss Discriminator: 0.699, loss Generator: 0.736
# Epoch [4/50] Batch 900/1563                   Loss Discriminator: 0.648, loss Generator: 0.842
# Epoch [4/50] Batch 1000/1563                   Loss Discriminator: 0.669, loss Generator: 0.803
# Epoch [4/50] Batch 1100/1563                   Loss Discriminator: 0.738, loss Generator: 0.765
# Epoch [4/50] Batch 1200/1563                   Loss Discriminator: 0.705, loss Generator: 0.858
# Epoch [4/50] Batch 1300/1563                   Loss Discriminator: 0.653, loss Generator: 0.897
# Epoch [4/50] Batch 1400/1563                   Loss Discriminator: 0.630, loss Generator: 0.935
# Epoch [4/50] Batch 1500/1563                   Loss Discriminator: 0.635, loss Generator: 0.857
# Fretchet Distance:  264.0584552513433
# Epoch [5/50] Batch 0/1563                   Loss Discriminator: 0.728, loss Generator: 1.033
# Epoch [5/50] Batch 100/1563                   Loss Discriminator: 0.626, loss Generator: 0.841
# Epoch [5/50] Batch 200/1563                   Loss Discriminator: 0.603, loss Generator: 0.947
# Epoch [5/50] Batch 300/1563                   Loss Discriminator: 0.707, loss Generator: 0.948
# Epoch [5/50] Batch 400/1563                   Loss Discriminator: 0.641, loss Generator: 0.689
# Epoch [5/50] Batch 500/1563                   Loss Discriminator: 0.681, loss Generator: 0.962
# Epoch [5/50] Batch 600/1563                   Loss Discriminator: 0.574, loss Generator: 0.973
# Epoch [5/50] Batch 700/1563                   Loss Discriminator: 0.580, loss Generator: 0.861
# Epoch [5/50] Batch 800/1563                   Loss Discriminator: 0.695, loss Generator: 0.773
# Epoch [5/50] Batch 900/1563                   Loss Discriminator: 0.565, loss Generator: 0.908
# Epoch [5/50] Batch 1000/1563                   Loss Discriminator: 0.583, loss Generator: 0.858
# Epoch [5/50] Batch 1100/1563                   Loss Discriminator: 0.640, loss Generator: 0.817
# Epoch [5/50] Batch 1200/1563                   Loss Discriminator: 0.668, loss Generator: 0.834
# Epoch [5/50] Batch 1300/1563                   Loss Discriminator: 0.731, loss Generator: 1.038
# Epoch [5/50] Batch 1400/1563                   Loss Discriminator: 0.596, loss Generator: 0.947
# Epoch [5/50] Batch 1500/1563                   Loss Discriminator: 0.578, loss Generator: 0.939
# Fretchet Distance:  280.1634639757273
# Epoch [6/50] Batch 0/1563                   Loss Discriminator: 0.659, loss Generator: 1.167
# Epoch [6/50] Batch 100/1563                   Loss Discriminator: 0.605, loss Generator: 0.882
# Epoch [6/50] Batch 200/1563                   Loss Discriminator: 0.686, loss Generator: 0.760
# Epoch [6/50] Batch 300/1563                   Loss Discriminator: 0.672, loss Generator: 0.796
# Epoch [6/50] Batch 400/1563                   Loss Discriminator: 0.679, loss Generator: 0.685
# Epoch [6/50] Batch 500/1563                   Loss Discriminator: 0.681, loss Generator: 0.743
# Epoch [6/50] Batch 600/1563                   Loss Discriminator: 0.669, loss Generator: 0.775
# Epoch [6/50] Batch 700/1563                   Loss Discriminator: 0.644, loss Generator: 0.818
# Epoch [6/50] Batch 800/1563                   Loss Discriminator: 0.598, loss Generator: 0.760
# Epoch [6/50] Batch 900/1563                   Loss Discriminator: 0.529, loss Generator: 0.904
# Epoch [6/50] Batch 1000/1563                   Loss Discriminator: 0.668, loss Generator: 0.896
# Epoch [6/50] Batch 1100/1563                   Loss Discriminator: 0.680, loss Generator: 0.800
# Epoch [6/50] Batch 1200/1563                   Loss Discriminator: 0.660, loss Generator: 0.808
# Epoch [6/50] Batch 1300/1563                   Loss Discriminator: 0.646, loss Generator: 0.776
# Epoch [6/50] Batch 1400/1563                   Loss Discriminator: 0.672, loss Generator: 0.941
# Epoch [6/50] Batch 1500/1563                   Loss Discriminator: 0.768, loss Generator: 0.979
# Fretchet Distance:  251.19108869759324
# Epoch [7/50] Batch 0/1563                   Loss Discriminator: 0.601, loss Generator: 0.844
# Epoch [7/50] Batch 100/1563                   Loss Discriminator: 0.584, loss Generator: 1.053
# Epoch [7/50] Batch 200/1563                   Loss Discriminator: 0.723, loss Generator: 0.777
# Epoch [7/50] Batch 300/1563                   Loss Discriminator: 0.704, loss Generator: 0.759
# Epoch [7/50] Batch 400/1563                   Loss Discriminator: 0.669, loss Generator: 0.907
# Epoch [7/50] Batch 500/1563                   Loss Discriminator: 0.566, loss Generator: 0.842
# Epoch [7/50] Batch 600/1563                   Loss Discriminator: 0.738, loss Generator: 0.703
# Epoch [7/50] Batch 700/1563                   Loss Discriminator: 0.613, loss Generator: 1.044
# Epoch [7/50] Batch 800/1563                   Loss Discriminator: 0.765, loss Generator: 1.132
# Epoch [7/50] Batch 900/1563                   Loss Discriminator: 0.723, loss Generator: 1.284
# Epoch [7/50] Batch 1000/1563                   Loss Discriminator: 0.568, loss Generator: 1.220
# Epoch [7/50] Batch 1100/1563                   Loss Discriminator: 0.567, loss Generator: 0.891
# Epoch [7/50] Batch 1200/1563                   Loss Discriminator: 0.629, loss Generator: 0.975
# Epoch [7/50] Batch 1300/1563                   Loss Discriminator: 0.607, loss Generator: 1.002
# Epoch [7/50] Batch 1400/1563                   Loss Discriminator: 0.593, loss Generator: 1.022
# Epoch [7/50] Batch 1500/1563                   Loss Discriminator: 0.462, loss Generator: 0.909
# Fretchet Distance:  244.29487348398226
# Epoch [8/50] Batch 0/1563                   Loss Discriminator: 0.736, loss Generator: 0.651
# Epoch [8/50] Batch 100/1563                   Loss Discriminator: 0.635, loss Generator: 0.985
# Epoch [8/50] Batch 200/1563                   Loss Discriminator: 0.539, loss Generator: 0.857
# Epoch [8/50] Batch 300/1563                   Loss Discriminator: 0.587, loss Generator: 0.872
# Epoch [8/50] Batch 400/1563                   Loss Discriminator: 0.535, loss Generator: 0.826
# Epoch [8/50] Batch 500/1563                   Loss Discriminator: 0.629, loss Generator: 0.893
# Epoch [8/50] Batch 600/1563                   Loss Discriminator: 0.534, loss Generator: 1.218
# Epoch [8/50] Batch 700/1563                   Loss Discriminator: 0.667, loss Generator: 1.387
# Epoch [8/50] Batch 800/1563                   Loss Discriminator: 0.708, loss Generator: 0.898
# Epoch [8/50] Batch 900/1563                   Loss Discriminator: 0.655, loss Generator: 0.881
# Epoch [8/50] Batch 1000/1563                   Loss Discriminator: 1.024, loss Generator: 1.561
# Epoch [8/50] Batch 1100/1563                   Loss Discriminator: 0.575, loss Generator: 0.900
# Epoch [8/50] Batch 1200/1563                   Loss Discriminator: 0.677, loss Generator: 1.081
# Epoch [8/50] Batch 1300/1563                   Loss Discriminator: 0.578, loss Generator: 1.048
# Epoch [8/50] Batch 1400/1563                   Loss Discriminator: 0.591, loss Generator: 0.878
# Epoch [8/50] Batch 1500/1563                   Loss Discriminator: 0.551, loss Generator: 1.298
# Fretchet Distance:  249.19329454884655
# Epoch [9/50] Batch 0/1563                   Loss Discriminator: 0.555, loss Generator: 0.780
# Epoch [9/50] Batch 100/1563                   Loss Discriminator: 0.622, loss Generator: 1.106
# Epoch [9/50] Batch 200/1563                   Loss Discriminator: 0.597, loss Generator: 1.177
# Epoch [9/50] Batch 300/1563                   Loss Discriminator: 0.602, loss Generator: 0.849
# Epoch [9/50] Batch 400/1563                   Loss Discriminator: 0.644, loss Generator: 0.905
# Epoch [9/50] Batch 500/1563                   Loss Discriminator: 0.595, loss Generator: 1.085
# Epoch [9/50] Batch 600/1563                   Loss Discriminator: 0.522, loss Generator: 0.977
# Epoch [9/50] Batch 700/1563                   Loss Discriminator: 0.613, loss Generator: 0.919
# Epoch [9/50] Batch 800/1563                   Loss Discriminator: 0.575, loss Generator: 0.983
# Epoch [9/50] Batch 900/1563                   Loss Discriminator: 0.646, loss Generator: 0.786
# Epoch [9/50] Batch 1000/1563                   Loss Discriminator: 0.692, loss Generator: 0.874
# Epoch [9/50] Batch 1100/1563                   Loss Discriminator: 0.576, loss Generator: 1.075
# Epoch [9/50] Batch 1200/1563                   Loss Discriminator: 0.588, loss Generator: 0.898
# Epoch [9/50] Batch 1300/1563                   Loss Discriminator: 0.667, loss Generator: 0.985
# Epoch [9/50] Batch 1400/1563                   Loss Discriminator: 0.746, loss Generator: 1.297
# Epoch [9/50] Batch 1500/1563                   Loss Discriminator: 0.609, loss Generator: 1.247
# Fretchet Distance:  259.42636525551825
# Epoch [10/50] Batch 0/1563                   Loss Discriminator: 0.507, loss Generator: 1.074
# Epoch [10/50] Batch 100/1563                   Loss Discriminator: 0.723, loss Generator: 0.815
# Epoch [10/50] Batch 200/1563                   Loss Discriminator: 0.603, loss Generator: 1.062
# Epoch [10/50] Batch 300/1563                   Loss Discriminator: 0.539, loss Generator: 0.965
# Epoch [10/50] Batch 400/1563                   Loss Discriminator: 0.650, loss Generator: 0.877
# Epoch [10/50] Batch 500/1563                   Loss Discriminator: 0.673, loss Generator: 0.816
# Epoch [10/50] Batch 600/1563                   Loss Discriminator: 0.662, loss Generator: 0.878
# Epoch [10/50] Batch 700/1563                   Loss Discriminator: 0.726, loss Generator: 1.207
# Epoch [10/50] Batch 800/1563                   Loss Discriminator: 0.494, loss Generator: 1.166
# Epoch [10/50] Batch 900/1563                   Loss Discriminator: 0.761, loss Generator: 1.099
# Epoch [10/50] Batch 1000/1563                   Loss Discriminator: 0.553, loss Generator: 1.586
# Epoch [10/50] Batch 1100/1563                   Loss Discriminator: 0.668, loss Generator: 0.753
# Epoch [10/50] Batch 1200/1563                   Loss Discriminator: 0.624, loss Generator: 0.960
# Epoch [10/50] Batch 1300/1563                   Loss Discriminator: 0.629, loss Generator: 1.397
# Epoch [10/50] Batch 1400/1563                   Loss Discriminator: 0.676, loss Generator: 0.806
# Epoch [10/50] Batch 1500/1563                   Loss Discriminator: 0.590, loss Generator: 1.144
# Fretchet Distance:  243.33596340208243
# Epoch [11/50] Batch 0/1563                   Loss Discriminator: 0.535, loss Generator: 1.019
# Epoch [11/50] Batch 100/1563                   Loss Discriminator: 0.709, loss Generator: 0.735
# Epoch [11/50] Batch 200/1563                   Loss Discriminator: 0.692, loss Generator: 0.863
# Epoch [11/50] Batch 300/1563                   Loss Discriminator: 0.693, loss Generator: 0.824
# Epoch [11/50] Batch 400/1563                   Loss Discriminator: 0.699, loss Generator: 0.825
# Epoch [11/50] Batch 500/1563                   Loss Discriminator: 0.569, loss Generator: 0.960
# Epoch [11/50] Batch 600/1563                   Loss Discriminator: 0.576, loss Generator: 0.856
# Epoch [11/50] Batch 700/1563                   Loss Discriminator: 0.662, loss Generator: 0.780
# Epoch [11/50] Batch 800/1563                   Loss Discriminator: 0.592, loss Generator: 0.913
# Epoch [11/50] Batch 900/1563                   Loss Discriminator: 0.614, loss Generator: 0.947
# Epoch [11/50] Batch 1000/1563                   Loss Discriminator: 0.669, loss Generator: 0.844
# Epoch [11/50] Batch 1100/1563                   Loss Discriminator: 0.683, loss Generator: 0.800
# Epoch [11/50] Batch 1200/1563                   Loss Discriminator: 0.677, loss Generator: 0.963
# Epoch [11/50] Batch 1300/1563                   Loss Discriminator: 0.612, loss Generator: 0.856
# Epoch [11/50] Batch 1400/1563                   Loss Discriminator: 0.692, loss Generator: 0.839
# Epoch [11/50] Batch 1500/1563                   Loss Discriminator: 0.552, loss Generator: 0.949
# Fretchet Distance:  254.53931500305745
# Epoch [12/50] Batch 0/1563                   Loss Discriminator: 0.635, loss Generator: 0.798
# Epoch [12/50] Batch 100/1563                   Loss Discriminator: 0.366, loss Generator: 1.241
# Epoch [12/50] Batch 200/1563                   Loss Discriminator: 0.652, loss Generator: 1.190
# Epoch [12/50] Batch 300/1563                   Loss Discriminator: 0.433, loss Generator: 0.894
# Epoch [12/50] Batch 400/1563                   Loss Discriminator: 0.572, loss Generator: 0.952
# Epoch [12/50] Batch 500/1563                   Loss Discriminator: 0.698, loss Generator: 0.820
# Epoch [12/50] Batch 600/1563                   Loss Discriminator: 0.503, loss Generator: 1.036
# Epoch [12/50] Batch 700/1563                   Loss Discriminator: 0.636, loss Generator: 0.776
# Epoch [12/50] Batch 800/1563                   Loss Discriminator: 0.596, loss Generator: 1.283
# Epoch [12/50] Batch 900/1563                   Loss Discriminator: 0.756, loss Generator: 1.150
# Epoch [12/50] Batch 1000/1563                   Loss Discriminator: 0.694, loss Generator: 1.163
# Epoch [12/50] Batch 1100/1563                   Loss Discriminator: 0.595, loss Generator: 0.982
# Epoch [12/50] Batch 1200/1563                   Loss Discriminator: 0.641, loss Generator: 0.834
# Epoch [12/50] Batch 1300/1563                   Loss Discriminator: 0.566, loss Generator: 1.091
# Epoch [12/50] Batch 1400/1563                   Loss Discriminator: 0.645, loss Generator: 0.870
# Epoch [12/50] Batch 1500/1563                   Loss Discriminator: 0.624, loss Generator: 0.869
# Fretchet Distance:  279.19547366635004
# Epoch [13/50] Batch 0/1563                   Loss Discriminator: 0.823, loss Generator: 1.340
# Epoch [13/50] Batch 100/1563                   Loss Discriminator: 0.555, loss Generator: 0.837
# Epoch [13/50] Batch 200/1563                   Loss Discriminator: 0.562, loss Generator: 1.060
# Epoch [13/50] Batch 300/1563                   Loss Discriminator: 0.651, loss Generator: 0.956
# Epoch [13/50] Batch 400/1563                   Loss Discriminator: 0.571, loss Generator: 1.052
# Epoch [13/50] Batch 500/1563                   Loss Discriminator: 0.612, loss Generator: 0.907
# Epoch [13/50] Batch 600/1563                   Loss Discriminator: 0.647, loss Generator: 0.882
# Epoch [13/50] Batch 700/1563                   Loss Discriminator: 0.572, loss Generator: 1.113
# Epoch [13/50] Batch 800/1563                   Loss Discriminator: 0.718, loss Generator: 1.204
# Epoch [13/50] Batch 900/1563                   Loss Discriminator: 0.851, loss Generator: 1.131
# Epoch [13/50] Batch 1000/1563                   Loss Discriminator: 0.558, loss Generator: 1.092
# Epoch [13/50] Batch 1100/1563                   Loss Discriminator: 0.608, loss Generator: 0.893
# Epoch [13/50] Batch 1200/1563                   Loss Discriminator: 0.649, loss Generator: 1.019
# Epoch [13/50] Batch 1300/1563                   Loss Discriminator: 0.357, loss Generator: 1.274
# Epoch [13/50] Batch 1400/1563                   Loss Discriminator: 0.649, loss Generator: 0.810
# Epoch [13/50] Batch 1500/1563                   Loss Discriminator: 0.641, loss Generator: 0.882
# Fretchet Distance:  262.5770477759744
# Epoch [14/50] Batch 0/1563                   Loss Discriminator: 0.710, loss Generator: 1.284
# Epoch [14/50] Batch 100/1563                   Loss Discriminator: 0.540, loss Generator: 1.240
# Epoch [14/50] Batch 200/1563                   Loss Discriminator: 0.662, loss Generator: 1.194
# Epoch [14/50] Batch 300/1563                   Loss Discriminator: 0.572, loss Generator: 0.948
# Epoch [14/50] Batch 400/1563                   Loss Discriminator: 0.645, loss Generator: 0.984
# Epoch [14/50] Batch 500/1563                   Loss Discriminator: 0.817, loss Generator: 1.073
# Epoch [14/50] Batch 600/1563                   Loss Discriminator: 0.553, loss Generator: 0.995
# Epoch [14/50] Batch 700/1563                   Loss Discriminator: 0.676, loss Generator: 0.890
# Epoch [14/50] Batch 800/1563                   Loss Discriminator: 0.647, loss Generator: 1.082
# Epoch [14/50] Batch 900/1563                   Loss Discriminator: 0.734, loss Generator: 1.135
# Epoch [14/50] Batch 1000/1563                   Loss Discriminator: 0.558, loss Generator: 1.216
# Epoch [14/50] Batch 1100/1563                   Loss Discriminator: 0.654, loss Generator: 0.896
# Epoch [14/50] Batch 1200/1563                   Loss Discriminator: 0.497, loss Generator: 1.410
# Epoch [14/50] Batch 1300/1563                   Loss Discriminator: 0.614, loss Generator: 0.985
# Epoch [14/50] Batch 1400/1563                   Loss Discriminator: 0.544, loss Generator: 0.929
# Epoch [14/50] Batch 1500/1563                   Loss Discriminator: 0.647, loss Generator: 0.874
# Fretchet Distance:  247.485039643609
# Epoch [15/50] Batch 0/1563                   Loss Discriminator: 0.623, loss Generator: 0.878
# Epoch [15/50] Batch 100/1563                   Loss Discriminator: 0.629, loss Generator: 0.865
# Epoch [15/50] Batch 200/1563                   Loss Discriminator: 0.577, loss Generator: 0.729
# Epoch [15/50] Batch 300/1563                   Loss Discriminator: 0.519, loss Generator: 0.745
# Epoch [15/50] Batch 400/1563                   Loss Discriminator: 0.558, loss Generator: 0.972
# Epoch [15/50] Batch 500/1563                   Loss Discriminator: 0.627, loss Generator: 0.864
# Epoch [15/50] Batch 600/1563                   Loss Discriminator: 0.633, loss Generator: 0.909
# Epoch [15/50] Batch 700/1563                   Loss Discriminator: 0.511, loss Generator: 1.197
# Epoch [15/50] Batch 800/1563                   Loss Discriminator: 0.642, loss Generator: 0.921
# Epoch [15/50] Batch 900/1563                   Loss Discriminator: 0.520, loss Generator: 1.085
# Epoch [15/50] Batch 1000/1563                   Loss Discriminator: 0.656, loss Generator: 1.010
# Epoch [15/50] Batch 1100/1563                   Loss Discriminator: 0.590, loss Generator: 1.197
# Epoch [15/50] Batch 1200/1563                   Loss Discriminator: 0.462, loss Generator: 1.177
# Epoch [15/50] Batch 1300/1563                   Loss Discriminator: 0.569, loss Generator: 1.248
# Epoch [15/50] Batch 1400/1563                   Loss Discriminator: 0.573, loss Generator: 1.016
# Epoch [15/50] Batch 1500/1563                   Loss Discriminator: 0.667, loss Generator: 1.056
# Fretchet Distance:  260.1628299426274
# Epoch [16/50] Batch 0/1563                   Loss Discriminator: 0.586, loss Generator: 1.045
# Epoch [16/50] Batch 100/1563                   Loss Discriminator: 0.674, loss Generator: 0.953
# Epoch [16/50] Batch 200/1563                   Loss Discriminator: 0.581, loss Generator: 1.011
# Epoch [16/50] Batch 300/1563                   Loss Discriminator: 0.606, loss Generator: 1.037
# Epoch [16/50] Batch 400/1563                   Loss Discriminator: 0.602, loss Generator: 0.927
# Epoch [16/50] Batch 500/1563                   Loss Discriminator: 0.602, loss Generator: 1.147
# Epoch [16/50] Batch 600/1563                   Loss Discriminator: 0.639, loss Generator: 0.973
# Epoch [16/50] Batch 700/1563                   Loss Discriminator: 0.733, loss Generator: 2.447
# Epoch [16/50] Batch 800/1563                   Loss Discriminator: 0.480, loss Generator: 1.084
# Epoch [16/50] Batch 900/1563                   Loss Discriminator: 0.598, loss Generator: 0.957
# Epoch [16/50] Batch 1000/1563                   Loss Discriminator: 0.529, loss Generator: 0.757
# Epoch [16/50] Batch 1100/1563                   Loss Discriminator: 0.633, loss Generator: 0.888
# Epoch [16/50] Batch 1200/1563                   Loss Discriminator: 0.580, loss Generator: 0.909
# Epoch [16/50] Batch 1300/1563                   Loss Discriminator: 0.473, loss Generator: 1.141
# Epoch [16/50] Batch 1400/1563                   Loss Discriminator: 0.577, loss Generator: 1.214
# Epoch [16/50] Batch 1500/1563                   Loss Discriminator: 0.602, loss Generator: 1.026
# Fretchet Distance:  267.13304744618574
# Epoch [17/50] Batch 0/1563                   Loss Discriminator: 0.212, loss Generator: 1.789
# Epoch [17/50] Batch 100/1563                   Loss Discriminator: 0.667, loss Generator: 0.858
# Epoch [17/50] Batch 200/1563                   Loss Discriminator: 0.678, loss Generator: 0.956
# Epoch [17/50] Batch 300/1563                   Loss Discriminator: 0.538, loss Generator: 1.064
# Epoch [17/50] Batch 400/1563                   Loss Discriminator: 0.578, loss Generator: 1.014
# Epoch [17/50] Batch 500/1563                   Loss Discriminator: 0.591, loss Generator: 1.025
# Epoch [17/50] Batch 600/1563                   Loss Discriminator: 0.620, loss Generator: 1.068
# Epoch [17/50] Batch 700/1563                   Loss Discriminator: 0.592, loss Generator: 1.023
# Epoch [17/50] Batch 800/1563                   Loss Discriminator: 0.574, loss Generator: 0.805
# Epoch [17/50] Batch 900/1563                   Loss Discriminator: 0.642, loss Generator: 0.930
# Epoch [17/50] Batch 1000/1563                   Loss Discriminator: 0.532, loss Generator: 1.424
# Epoch [17/50] Batch 1100/1563                   Loss Discriminator: 0.485, loss Generator: 1.206
# Epoch [17/50] Batch 1200/1563                   Loss Discriminator: 0.331, loss Generator: 1.275
# Epoch [17/50] Batch 1300/1563                   Loss Discriminator: 0.592, loss Generator: 1.235
# Epoch [17/50] Batch 1400/1563                   Loss Discriminator: 0.668, loss Generator: 0.940
# Epoch [17/50] Batch 1500/1563                   Loss Discriminator: 0.627, loss Generator: 0.898
# Fretchet Distance:  259.11354432172357
# Epoch [18/50] Batch 0/1563                   Loss Discriminator: 0.547, loss Generator: 1.050
# Epoch [18/50] Batch 100/1563                   Loss Discriminator: 0.540, loss Generator: 1.593
# Epoch [18/50] Batch 200/1563                   Loss Discriminator: 0.583, loss Generator: 0.964
# Epoch [18/50] Batch 300/1563                   Loss Discriminator: 0.453, loss Generator: 1.176
# Epoch [18/50] Batch 400/1563                   Loss Discriminator: 0.504, loss Generator: 1.241
# Epoch [18/50] Batch 500/1563                   Loss Discriminator: 0.590, loss Generator: 1.145
# Epoch [18/50] Batch 600/1563                   Loss Discriminator: 0.578, loss Generator: 1.322
# Epoch [18/50] Batch 700/1563                   Loss Discriminator: 0.581, loss Generator: 1.156
# Epoch [18/50] Batch 800/1563                   Loss Discriminator: 0.487, loss Generator: 1.082
# Epoch [18/50] Batch 900/1563                   Loss Discriminator: 0.533, loss Generator: 0.735
# Epoch [18/50] Batch 1000/1563                   Loss Discriminator: 0.594, loss Generator: 0.809
# Epoch [18/50] Batch 1100/1563                   Loss Discriminator: 0.456, loss Generator: 1.184
# Epoch [18/50] Batch 1200/1563                   Loss Discriminator: 0.595, loss Generator: 1.011
# Epoch [18/50] Batch 1300/1563                   Loss Discriminator: 0.753, loss Generator: 0.425
# Epoch [18/50] Batch 1400/1563                   Loss Discriminator: 0.545, loss Generator: 1.005
# Epoch [18/50] Batch 1500/1563                   Loss Discriminator: 0.559, loss Generator: 1.094
# Fretchet Distance:  263.2242696245044
# Epoch [19/50] Batch 0/1563                   Loss Discriminator: 0.542, loss Generator: 1.212
# Epoch [19/50] Batch 100/1563                   Loss Discriminator: 0.551, loss Generator: 0.988
# Epoch [19/50] Batch 200/1563                   Loss Discriminator: 0.630, loss Generator: 1.113
# Epoch [19/50] Batch 300/1563                   Loss Discriminator: 0.604, loss Generator: 1.388
# Epoch [19/50] Batch 400/1563                   Loss Discriminator: 0.586, loss Generator: 1.249
# Epoch [19/50] Batch 500/1563                   Loss Discriminator: 0.564, loss Generator: 1.257
# Epoch [19/50] Batch 600/1563                   Loss Discriminator: 0.560, loss Generator: 0.944
# Epoch [19/50] Batch 700/1563                   Loss Discriminator: 0.589, loss Generator: 0.960
# Epoch [19/50] Batch 800/1563                   Loss Discriminator: 0.441, loss Generator: 1.256
# Epoch [19/50] Batch 900/1563                   Loss Discriminator: 0.456, loss Generator: 1.321
# Epoch [19/50] Batch 1000/1563                   Loss Discriminator: 0.571, loss Generator: 0.989
# Epoch [19/50] Batch 1100/1563                   Loss Discriminator: 0.506, loss Generator: 1.421
# Epoch [19/50] Batch 1200/1563                   Loss Discriminator: 0.836, loss Generator: 1.158
# Epoch [19/50] Batch 1300/1563                   Loss Discriminator: 0.485, loss Generator: 1.192
# Epoch [19/50] Batch 1400/1563                   Loss Discriminator: 0.420, loss Generator: 1.582
# Epoch [19/50] Batch 1500/1563                   Loss Discriminator: 0.439, loss Generator: 1.345
# Fretchet Distance:  252.21729076429554
# Epoch [20/50] Batch 0/1563                   Loss Discriminator: 0.523, loss Generator: 1.133
# Epoch [20/50] Batch 100/1563                   Loss Discriminator: 0.437, loss Generator: 1.339
# Epoch [20/50] Batch 200/1563                   Loss Discriminator: 0.439, loss Generator: 1.446
# Epoch [20/50] Batch 300/1563                   Loss Discriminator: 0.515, loss Generator: 1.153
# Epoch [20/50] Batch 400/1563                   Loss Discriminator: 0.667, loss Generator: 1.588
# Epoch [20/50] Batch 500/1563                   Loss Discriminator: 0.601, loss Generator: 1.141
# Epoch [20/50] Batch 600/1563                   Loss Discriminator: 0.543, loss Generator: 1.389
# Epoch [20/50] Batch 700/1563                   Loss Discriminator: 0.525, loss Generator: 1.836
# Epoch [20/50] Batch 800/1563                   Loss Discriminator: 0.427, loss Generator: 1.675
# Epoch [20/50] Batch 900/1563                   Loss Discriminator: 0.473, loss Generator: 1.259
# Epoch [20/50] Batch 1000/1563                   Loss Discriminator: 0.429, loss Generator: 1.193
# Epoch [20/50] Batch 1100/1563                   Loss Discriminator: 0.259, loss Generator: 1.493
# Epoch [20/50] Batch 1200/1563                   Loss Discriminator: 0.547, loss Generator: 1.121
# Epoch [20/50] Batch 1300/1563                   Loss Discriminator: 0.534, loss Generator: 1.193
# Epoch [20/50] Batch 1400/1563                   Loss Discriminator: 0.400, loss Generator: 1.583
# Epoch [20/50] Batch 1500/1563                   Loss Discriminator: 0.523, loss Generator: 1.203
# Fretchet Distance:  260.8630384212667
# Epoch [21/50] Batch 0/1563                   Loss Discriminator: 0.529, loss Generator: 1.229
# Epoch [21/50] Batch 100/1563                   Loss Discriminator: 0.506, loss Generator: 1.683
# Epoch [21/50] Batch 200/1563                   Loss Discriminator: 0.555, loss Generator: 1.117
# Epoch [21/50] Batch 300/1563                   Loss Discriminator: 0.519, loss Generator: 1.536
# Epoch [21/50] Batch 400/1563                   Loss Discriminator: 0.505, loss Generator: 1.173
# Epoch [21/50] Batch 500/1563                   Loss Discriminator: 0.423, loss Generator: 1.259
# Epoch [21/50] Batch 600/1563                   Loss Discriminator: 0.473, loss Generator: 1.179
# Epoch [21/50] Batch 700/1563                   Loss Discriminator: 0.349, loss Generator: 1.381
# Epoch [21/50] Batch 800/1563                   Loss Discriminator: 0.528, loss Generator: 1.234
# Epoch [21/50] Batch 900/1563                   Loss Discriminator: 0.460, loss Generator: 1.263
# Epoch [21/50] Batch 1000/1563                   Loss Discriminator: 0.214, loss Generator: 1.709
# Epoch [21/50] Batch 1100/1563                   Loss Discriminator: 0.509, loss Generator: 1.164
# Epoch [21/50] Batch 1200/1563                   Loss Discriminator: 0.597, loss Generator: 1.120
# Epoch [21/50] Batch 1300/1563                   Loss Discriminator: 0.515, loss Generator: 1.288
# Epoch [21/50] Batch 1400/1563                   Loss Discriminator: 0.684, loss Generator: 2.017
# Epoch [21/50] Batch 1500/1563                   Loss Discriminator: 0.490, loss Generator: 1.347
# Fretchet Distance:  266.0437573921558
# Epoch [22/50] Batch 0/1563                   Loss Discriminator: 0.503, loss Generator: 1.184
# Epoch [22/50] Batch 100/1563                   Loss Discriminator: 0.289, loss Generator: 1.558
# Epoch [22/50] Batch 200/1563                   Loss Discriminator: 0.574, loss Generator: 1.283
# Epoch [22/50] Batch 300/1563                   Loss Discriminator: 0.428, loss Generator: 1.264
# Epoch [22/50] Batch 400/1563                   Loss Discriminator: 0.498, loss Generator: 1.439
# Epoch [22/50] Batch 500/1563                   Loss Discriminator: 0.547, loss Generator: 1.127
# Epoch [22/50] Batch 600/1563                   Loss Discriminator: 0.337, loss Generator: 2.012
# Epoch [22/50] Batch 700/1563                   Loss Discriminator: 0.454, loss Generator: 1.375
# Epoch [22/50] Batch 800/1563                   Loss Discriminator: 0.468, loss Generator: 1.290
# Epoch [22/50] Batch 900/1563                   Loss Discriminator: 0.458, loss Generator: 1.669
# Epoch [22/50] Batch 1000/1563                   Loss Discriminator: 0.533, loss Generator: 1.448
# Epoch [22/50] Batch 1100/1563                   Loss Discriminator: 0.514, loss Generator: 1.140
# Epoch [22/50] Batch 1200/1563                   Loss Discriminator: 0.473, loss Generator: 1.240
# Epoch [22/50] Batch 1300/1563                   Loss Discriminator: 0.562, loss Generator: 1.107
# Epoch [22/50] Batch 1400/1563                   Loss Discriminator: 0.506, loss Generator: 1.134
# Epoch [22/50] Batch 1500/1563                   Loss Discriminator: 0.543, loss Generator: 1.136
# Fretchet Distance:  271.9824545742261
# Epoch [23/50] Batch 0/1563                   Loss Discriminator: 0.636, loss Generator: 1.134
# Epoch [23/50] Batch 100/1563                   Loss Discriminator: 0.503, loss Generator: 1.314
# Epoch [23/50] Batch 200/1563                   Loss Discriminator: 0.465, loss Generator: 1.418
# Epoch [23/50] Batch 300/1563                   Loss Discriminator: 0.451, loss Generator: 2.325
# Epoch [23/50] Batch 400/1563                   Loss Discriminator: 0.468, loss Generator: 1.430
# Epoch [23/50] Batch 500/1563                   Loss Discriminator: 0.433, loss Generator: 1.241
# Epoch [23/50] Batch 600/1563                   Loss Discriminator: 0.391, loss Generator: 1.327
# Epoch [23/50] Batch 700/1563                   Loss Discriminator: 0.582, loss Generator: 1.399
# Epoch [23/50] Batch 800/1563                   Loss Discriminator: 0.546, loss Generator: 1.540
# Epoch [23/50] Batch 900/1563                   Loss Discriminator: 0.584, loss Generator: 1.211
# Epoch [23/50] Batch 1000/1563                   Loss Discriminator: 0.581, loss Generator: 1.594
# Epoch [23/50] Batch 1100/1563                   Loss Discriminator: 0.701, loss Generator: 2.760
# Epoch [23/50] Batch 1200/1563                   Loss Discriminator: 0.435, loss Generator: 1.535
# Epoch [23/50] Batch 1300/1563                   Loss Discriminator: 0.357, loss Generator: 2.064
# Epoch [23/50] Batch 1400/1563                   Loss Discriminator: 0.503, loss Generator: 1.254
# Epoch [23/50] Batch 1500/1563                   Loss Discriminator: 0.575, loss Generator: 1.377
# Fretchet Distance:  257.2530866169
# Epoch [24/50] Batch 0/1563                   Loss Discriminator: 0.545, loss Generator: 1.206
# Epoch [24/50] Batch 100/1563                   Loss Discriminator: 0.532, loss Generator: 1.990
# Epoch [24/50] Batch 200/1563                   Loss Discriminator: 0.498, loss Generator: 0.955
# Epoch [24/50] Batch 300/1563                   Loss Discriminator: 0.307, loss Generator: 1.639
# Epoch [24/50] Batch 400/1563                   Loss Discriminator: 0.403, loss Generator: 1.520
# Epoch [24/50] Batch 500/1563                   Loss Discriminator: 0.366, loss Generator: 2.011
# Epoch [24/50] Batch 600/1563                   Loss Discriminator: 0.566, loss Generator: 1.326
# Epoch [24/50] Batch 700/1563                   Loss Discriminator: 0.411, loss Generator: 2.360
# Epoch [24/50] Batch 800/1563                   Loss Discriminator: 0.471, loss Generator: 1.369
# Epoch [24/50] Batch 900/1563                   Loss Discriminator: 0.520, loss Generator: 1.375
# Epoch [24/50] Batch 1000/1563                   Loss Discriminator: 0.421, loss Generator: 1.345
# Epoch [24/50] Batch 1100/1563                   Loss Discriminator: 0.282, loss Generator: 2.330
# Epoch [24/50] Batch 1200/1563                   Loss Discriminator: 0.435, loss Generator: 1.361
# Epoch [24/50] Batch 1300/1563                   Loss Discriminator: 0.559, loss Generator: 1.266
# Epoch [24/50] Batch 1400/1563                   Loss Discriminator: 0.393, loss Generator: 1.507
# Epoch [24/50] Batch 1500/1563                   Loss Discriminator: 0.484, loss Generator: 1.362
# Fretchet Distance:  246.40017470766762
# Epoch [25/50] Batch 0/1563                   Loss Discriminator: 0.830, loss Generator: 1.460
# Epoch [25/50] Batch 100/1563                   Loss Discriminator: 0.452, loss Generator: 1.531
# Epoch [25/50] Batch 200/1563                   Loss Discriminator: 0.325, loss Generator: 1.692
# Epoch [25/50] Batch 300/1563                   Loss Discriminator: 0.558, loss Generator: 1.340
# Epoch [25/50] Batch 400/1563                   Loss Discriminator: 0.520, loss Generator: 1.438
# Epoch [25/50] Batch 500/1563                   Loss Discriminator: 0.474, loss Generator: 1.418
# Epoch [25/50] Batch 600/1563                   Loss Discriminator: 0.565, loss Generator: 1.251
# Epoch [25/50] Batch 700/1563                   Loss Discriminator: 0.468, loss Generator: 1.439
# Epoch [25/50] Batch 800/1563                   Loss Discriminator: 0.504, loss Generator: 1.712
# Epoch [25/50] Batch 900/1563                   Loss Discriminator: 0.563, loss Generator: 1.365
# Epoch [25/50] Batch 1000/1563                   Loss Discriminator: 0.472, loss Generator: 1.189
# Epoch [25/50] Batch 1100/1563                   Loss Discriminator: 0.545, loss Generator: 1.458
# Epoch [25/50] Batch 1200/1563                   Loss Discriminator: 0.518, loss Generator: 1.357
# Epoch [25/50] Batch 1300/1563                   Loss Discriminator: 0.462, loss Generator: 1.399
# Epoch [25/50] Batch 1400/1563                   Loss Discriminator: 0.501, loss Generator: 1.571
# Epoch [25/50] Batch 1500/1563                   Loss Discriminator: 0.463, loss Generator: 1.394
# Fretchet Distance:  236.51809934543246
# Epoch [26/50] Batch 0/1563                   Loss Discriminator: 0.318, loss Generator: 2.263
# Epoch [26/50] Batch 100/1563                   Loss Discriminator: 0.418, loss Generator: 1.645
# Epoch [26/50] Batch 200/1563                   Loss Discriminator: 0.281, loss Generator: 1.911
# Epoch [26/50] Batch 300/1563                   Loss Discriminator: 0.429, loss Generator: 1.630
# Epoch [26/50] Batch 400/1563                   Loss Discriminator: 0.790, loss Generator: 1.681
# Epoch [26/50] Batch 500/1563                   Loss Discriminator: 0.494, loss Generator: 1.610
# Epoch [26/50] Batch 600/1563                   Loss Discriminator: 0.369, loss Generator: 1.571
# Epoch [26/50] Batch 700/1563                   Loss Discriminator: 0.424, loss Generator: 1.376
# Epoch [26/50] Batch 800/1563                   Loss Discriminator: 0.506, loss Generator: 1.336
# Epoch [26/50] Batch 900/1563                   Loss Discriminator: 0.537, loss Generator: 1.327
# Epoch [26/50] Batch 1000/1563                   Loss Discriminator: 0.416, loss Generator: 1.423
# Epoch [26/50] Batch 1100/1563                   Loss Discriminator: 0.457, loss Generator: 1.413
# Epoch [26/50] Batch 1200/1563                   Loss Discriminator: 0.384, loss Generator: 1.722
# Epoch [26/50] Batch 1300/1563                   Loss Discriminator: 0.458, loss Generator: 1.406
# Epoch [26/50] Batch 1400/1563                   Loss Discriminator: 0.390, loss Generator: 1.507
# Epoch [26/50] Batch 1500/1563                   Loss Discriminator: 0.525, loss Generator: 1.439
# Fretchet Distance:  258.22941581266156
# Epoch [27/50] Batch 0/1563                   Loss Discriminator: 0.495, loss Generator: 2.115
# Epoch [27/50] Batch 100/1563                   Loss Discriminator: 0.429, loss Generator: 1.905
# Epoch [27/50] Batch 200/1563                   Loss Discriminator: 0.444, loss Generator: 1.696
# Epoch [27/50] Batch 300/1563                   Loss Discriminator: 0.448, loss Generator: 1.557
# Epoch [27/50] Batch 400/1563                   Loss Discriminator: 0.363, loss Generator: 1.383
# Epoch [27/50] Batch 500/1563                   Loss Discriminator: 0.467, loss Generator: 1.493
# Epoch [27/50] Batch 600/1563                   Loss Discriminator: 0.358, loss Generator: 1.510
# Epoch [27/50] Batch 700/1563                   Loss Discriminator: 0.223, loss Generator: 1.842
# Epoch [27/50] Batch 800/1563                   Loss Discriminator: 0.486, loss Generator: 1.388
# Epoch [27/50] Batch 900/1563                   Loss Discriminator: 0.342, loss Generator: 1.826
# Epoch [27/50] Batch 1000/1563                   Loss Discriminator: 0.424, loss Generator: 1.762
# Epoch [27/50] Batch 1100/1563                   Loss Discriminator: 0.382, loss Generator: 1.469
# Epoch [27/50] Batch 1200/1563                   Loss Discriminator: 0.310, loss Generator: 1.722
# Epoch [27/50] Batch 1300/1563                   Loss Discriminator: 0.453, loss Generator: 1.479
# Epoch [27/50] Batch 1400/1563                   Loss Discriminator: 0.627, loss Generator: 1.505
# Epoch [27/50] Batch 1500/1563                   Loss Discriminator: 0.486, loss Generator: 1.361
# Fretchet Distance:  256.8769344673622
# Epoch [28/50] Batch 0/1563                   Loss Discriminator: 0.501, loss Generator: 1.091
# Epoch [28/50] Batch 100/1563                   Loss Discriminator: 0.388, loss Generator: 1.707
# Epoch [28/50] Batch 200/1563                   Loss Discriminator: 0.375, loss Generator: 1.925
# Epoch [28/50] Batch 300/1563                   Loss Discriminator: 0.485, loss Generator: 1.464
# Epoch [28/50] Batch 400/1563                   Loss Discriminator: 0.232, loss Generator: 1.724
# Epoch [28/50] Batch 500/1563                   Loss Discriminator: 0.373, loss Generator: 1.677
# Epoch [28/50] Batch 600/1563                   Loss Discriminator: 0.451, loss Generator: 1.741
# Epoch [28/50] Batch 700/1563                   Loss Discriminator: 0.234, loss Generator: 1.893
# Epoch [28/50] Batch 800/1563                   Loss Discriminator: 0.386, loss Generator: 1.527
# Epoch [28/50] Batch 900/1563                   Loss Discriminator: 0.470, loss Generator: 1.576
# Epoch [28/50] Batch 1000/1563                   Loss Discriminator: 0.597, loss Generator: 0.564
# Epoch [28/50] Batch 1100/1563                   Loss Discriminator: 0.371, loss Generator: 1.950
# Epoch [28/50] Batch 1200/1563                   Loss Discriminator: 0.509, loss Generator: 2.273
# Epoch [28/50] Batch 1300/1563                   Loss Discriminator: 0.385, loss Generator: 1.871
# Epoch [28/50] Batch 1400/1563                   Loss Discriminator: 0.341, loss Generator: 1.785
# Epoch [28/50] Batch 1500/1563                   Loss Discriminator: 0.381, loss Generator: 1.616
# Fretchet Distance:  276.4465159203604
# Epoch [29/50] Batch 0/1563                   Loss Discriminator: 0.268, loss Generator: 2.327
# Epoch [29/50] Batch 100/1563                   Loss Discriminator: 0.380, loss Generator: 1.503
# Epoch [29/50] Batch 200/1563                   Loss Discriminator: 0.376, loss Generator: 1.925
# Epoch [29/50] Batch 300/1563                   Loss Discriminator: 0.280, loss Generator: 2.073
# Epoch [29/50] Batch 400/1563                   Loss Discriminator: 0.331, loss Generator: 2.047
# Epoch [29/50] Batch 500/1563                   Loss Discriminator: 0.306, loss Generator: 2.006
# Epoch [29/50] Batch 600/1563                   Loss Discriminator: 0.258, loss Generator: 2.121
# Epoch [29/50] Batch 700/1563                   Loss Discriminator: 0.263, loss Generator: 2.610
# Epoch [29/50] Batch 800/1563                   Loss Discriminator: 0.473, loss Generator: 1.852
# Epoch [29/50] Batch 900/1563                   Loss Discriminator: 0.472, loss Generator: 1.630
# Epoch [29/50] Batch 1000/1563                   Loss Discriminator: 0.363, loss Generator: 1.853
# Epoch [29/50] Batch 1100/1563                   Loss Discriminator: 0.432, loss Generator: 1.683
# Epoch [29/50] Batch 1200/1563                   Loss Discriminator: 0.380, loss Generator: 1.715
# Epoch [29/50] Batch 1300/1563                   Loss Discriminator: 0.476, loss Generator: 1.449
# Epoch [29/50] Batch 1400/1563                   Loss Discriminator: 0.646, loss Generator: 1.629
# Epoch [29/50] Batch 1500/1563                   Loss Discriminator: 0.342, loss Generator: 1.595
# Fretchet Distance:  252.83882323868647
# Epoch [30/50] Batch 0/1563                   Loss Discriminator: 0.334, loss Generator: 1.797
# Epoch [30/50] Batch 100/1563                   Loss Discriminator: 0.400, loss Generator: 1.829
# Epoch [30/50] Batch 200/1563                   Loss Discriminator: 0.583, loss Generator: 2.083
# Epoch [30/50] Batch 300/1563                   Loss Discriminator: 0.447, loss Generator: 1.730
# Epoch [30/50] Batch 400/1563                   Loss Discriminator: 0.439, loss Generator: 1.692
# Epoch [30/50] Batch 500/1563                   Loss Discriminator: 0.344, loss Generator: 1.844
# Epoch [30/50] Batch 600/1563                   Loss Discriminator: 0.209, loss Generator: 2.371
# Epoch [30/50] Batch 700/1563                   Loss Discriminator: 0.366, loss Generator: 2.740
# Epoch [30/50] Batch 800/1563                   Loss Discriminator: 0.370, loss Generator: 2.280
# Epoch [30/50] Batch 900/1563                   Loss Discriminator: 0.232, loss Generator: 2.035
# Epoch [30/50] Batch 1000/1563                   Loss Discriminator: 0.497, loss Generator: 1.772
# Epoch [30/50] Batch 1100/1563                   Loss Discriminator: 0.279, loss Generator: 1.877
# Epoch [30/50] Batch 1200/1563                   Loss Discriminator: 0.248, loss Generator: 1.585
# Epoch [30/50] Batch 1300/1563                   Loss Discriminator: 0.297, loss Generator: 1.993
# Epoch [30/50] Batch 1400/1563                   Loss Discriminator: 0.375, loss Generator: 1.865
# Epoch [30/50] Batch 1500/1563                   Loss Discriminator: 0.439, loss Generator: 1.539
# Fretchet Distance:  244.27696846699365
# Epoch [31/50] Batch 0/1563                   Loss Discriminator: 0.315, loss Generator: 2.055
# Epoch [31/50] Batch 100/1563                   Loss Discriminator: 0.297, loss Generator: 2.329
# Epoch [31/50] Batch 200/1563                   Loss Discriminator: 0.454, loss Generator: 1.861
# Epoch [31/50] Batch 300/1563                   Loss Discriminator: 0.358, loss Generator: 2.044
# Epoch [31/50] Batch 400/1563                   Loss Discriminator: 0.520, loss Generator: 2.320
# Epoch [31/50] Batch 500/1563                   Loss Discriminator: 0.425, loss Generator: 1.914
# Epoch [31/50] Batch 600/1563                   Loss Discriminator: 0.326, loss Generator: 2.141
# Epoch [31/50] Batch 700/1563                   Loss Discriminator: 0.308, loss Generator: 2.135
# ...
# Epoch [40/50] Batch 1500/1563                   Loss Discriminator: 0.312, loss Generator: 2.579
# Fretchet Distance:  280.9508661762187
# Epoch [41/50] Batch 0/1563                   Loss Discriminator: 0.221, loss Generator: 2.643
# Epoch [41/50] Batch 100/1563                   Loss Discriminator: 0.155, loss Generator: 3.230
# Epoch [41/50] Batch 200/1563                   Loss Discriminator: 0.291, loss Generator: 2.626
# Epoch [41/50] Batch 300/1563                   Loss Discriminator: 0.347, loss Generator: 2.510
# Epoch [41/50] Batch 400/1563                   Loss Discriminator: 0.202, loss Generator: 3.059
# Epoch [41/50] Batch 500/1563                   Loss Discriminator: 0.228, loss Generator: 2.828
# Epoch [41/50] Batch 600/1563                   Loss Discriminator: 0.287, loss Generator: 2.726
# Epoch [41/50] Batch 700/1563                   Loss Discriminator: 0.144, loss Generator: 3.187
# Epoch [41/50] Batch 800/1563                   Loss Discriminator: 0.239, loss Generator: 3.449
# Epoch [41/50] Batch 900/1563                   Loss Discriminator: 0.205, loss Generator: 3.269
# Epoch [41/50] Batch 1000/1563                   Loss Discriminator: 0.302, loss Generator: 1.972
# Epoch [41/50] Batch 1100/1563                   Loss Discriminator: 0.304, loss Generator: 2.579
# Epoch [41/50] Batch 1200/1563                   Loss Discriminator: 0.141, loss Generator: 3.258
# Epoch [41/50] Batch 1300/1563                   Loss Discriminator: 0.190, loss Generator: 3.327
# Epoch [41/50] Batch 1400/1563                   Loss Discriminator: 0.154, loss Generator: 3.319
# Epoch [41/50] Batch 1500/1563                   Loss Discriminator: 0.333, loss Generator: 2.898
# Fretchet Distance:  261.18150027224647
# Epoch [42/50] Batch 0/1563                   Loss Discriminator: 0.315, loss Generator: 3.619
# Epoch [42/50] Batch 100/1563                   Loss Discriminator: 0.173, loss Generator: 3.388
# Epoch [42/50] Batch 200/1563                   Loss Discriminator: 0.120, loss Generator: 3.634
# Epoch [42/50] Batch 300/1563                   Loss Discriminator: 0.365, loss Generator: 3.848
# Epoch [42/50] Batch 400/1563                   Loss Discriminator: 0.197, loss Generator: 2.857
# Epoch [42/50] Batch 500/1563                   Loss Discriminator: 0.386, loss Generator: 2.435
# Epoch [42/50] Batch 600/1563                   Loss Discriminator: 0.282, loss Generator: 2.998
# Epoch [42/50] Batch 700/1563                   Loss Discriminator: 0.250, loss Generator: 3.015
# Epoch [42/50] Batch 800/1563                   Loss Discriminator: 0.283, loss Generator: 3.337
# Epoch [42/50] Batch 900/1563                   Loss Discriminator: 0.293, loss Generator: 3.201
# Epoch [42/50] Batch 1000/1563                   Loss Discriminator: 0.182, loss Generator: 2.652
# Epoch [42/50] Batch 1100/1563                   Loss Discriminator: 0.254, loss Generator: 3.464
# Epoch [42/50] Batch 1200/1563                   Loss Discriminator: 0.204, loss Generator: 2.948
# Epoch [42/50] Batch 1300/1563                   Loss Discriminator: 0.343, loss Generator: 2.654
# Epoch [42/50] Batch 1400/1563                   Loss Discriminator: 0.217, loss Generator: 3.421
# Epoch [42/50] Batch 1500/1563                   Loss Discriminator: 0.175, loss Generator: 2.987
# Fretchet Distance:  266.3249991645097
# Epoch [43/50] Batch 0/1563                   Loss Discriminator: 0.179, loss Generator: 3.225
# Epoch [43/50] Batch 100/1563                   Loss Discriminator: 0.130, loss Generator: 3.468
# Epoch [43/50] Batch 200/1563                   Loss Discriminator: 0.124, loss Generator: 3.433
# Epoch [43/50] Batch 300/1563                   Loss Discriminator: 0.195, loss Generator: 4.854
# Epoch [43/50] Batch 400/1563                   Loss Discriminator: 0.223, loss Generator: 2.862
# Epoch [43/50] Batch 500/1563                   Loss Discriminator: 0.222, loss Generator: 3.154
# Epoch [43/50] Batch 600/1563                   Loss Discriminator: 0.200, loss Generator: 3.382
# Epoch [43/50] Batch 700/1563                   Loss Discriminator: 0.186, loss Generator: 2.688
# Epoch [43/50] Batch 800/1563                   Loss Discriminator: 0.127, loss Generator: 3.810
# Epoch [43/50] Batch 900/1563                   Loss Discriminator: 0.143, loss Generator: 3.752
# Epoch [43/50] Batch 1000/1563                   Loss Discriminator: 0.249, loss Generator: 4.106
# Epoch [43/50] Batch 1100/1563                   Loss Discriminator: 0.192, loss Generator: 3.658
# Epoch [43/50] Batch 1200/1563                   Loss Discriminator: 0.226, loss Generator: 3.037
# Epoch [43/50] Batch 1300/1563                   Loss Discriminator: 0.225, loss Generator: 3.177
# Epoch [43/50] Batch 1400/1563                   Loss Discriminator: 0.266, loss Generator: 3.137
# Epoch [43/50] Batch 1500/1563                   Loss Discriminator: 0.181, loss Generator: 4.081
# Fretchet Distance:  240.72917544217364
# Epoch [44/50] Batch 0/1563                   Loss Discriminator: 0.321, loss Generator: 3.206
# Epoch [44/50] Batch 100/1563                   Loss Discriminator: 0.177, loss Generator: 3.251
# Epoch [44/50] Batch 200/1563                   Loss Discriminator: 0.201, loss Generator: 3.058
# Epoch [44/50] Batch 300/1563                   Loss Discriminator: 0.121, loss Generator: 3.231
# Epoch [44/50] Batch 400/1563                   Loss Discriminator: 0.121, loss Generator: 4.064
# Epoch [44/50] Batch 500/1563                   Loss Discriminator: 0.276, loss Generator: 2.775
# Epoch [44/50] Batch 600/1563                   Loss Discriminator: 0.127, loss Generator: 4.350
# Epoch [44/50] Batch 700/1563                   Loss Discriminator: 0.280, loss Generator: 2.563
# Epoch [44/50] Batch 800/1563                   Loss Discriminator: 0.197, loss Generator: 3.001
# Epoch [44/50] Batch 900/1563                   Loss Discriminator: 0.137, loss Generator: 3.521
# Epoch [44/50] Batch 1000/1563                   Loss Discriminator: 0.178, loss Generator: 3.421
# Epoch [44/50] Batch 1100/1563                   Loss Discriminator: 0.158, loss Generator: 3.569
# Epoch [44/50] Batch 1200/1563                   Loss Discriminator: 0.199, loss Generator: 3.915
# Epoch [44/50] Batch 1300/1563                   Loss Discriminator: 0.250, loss Generator: 2.664
# Epoch [44/50] Batch 1400/1563                   Loss Discriminator: 0.099, loss Generator: 3.747
# Epoch [44/50] Batch 1500/1563                   Loss Discriminator: 0.206, loss Generator: 3.553
# Fretchet Distance:  281.00214247484774
# Epoch [45/50] Batch 0/1563                   Loss Discriminator: 0.222, loss Generator: 3.545
# Epoch [45/50] Batch 100/1563                   Loss Discriminator: 0.136, loss Generator: 3.960
# Epoch [45/50] Batch 200/1563                   Loss Discriminator: 0.203, loss Generator: 3.066
# Epoch [45/50] Batch 300/1563                   Loss Discriminator: 0.268, loss Generator: 3.231
# Epoch [45/50] Batch 400/1563                   Loss Discriminator: 0.205, loss Generator: 4.166
# Epoch [45/50] Batch 500/1563                   Loss Discriminator: 0.119, loss Generator: 3.562
# Epoch [45/50] Batch 600/1563                   Loss Discriminator: 0.232, loss Generator: 3.334
# Epoch [45/50] Batch 700/1563                   Loss Discriminator: 0.094, loss Generator: 3.494
# Epoch [45/50] Batch 800/1563                   Loss Discriminator: 0.082, loss Generator: 3.842
# Epoch [45/50] Batch 900/1563                   Loss Discriminator: 0.132, loss Generator: 3.886
# Epoch [45/50] Batch 1000/1563                   Loss Discriminator: 0.215, loss Generator: 3.566
# Epoch [45/50] Batch 1100/1563                   Loss Discriminator: 0.146, loss Generator: 3.275
# Epoch [45/50] Batch 1200/1563                   Loss Discriminator: 0.234, loss Generator: 3.837
# Epoch [45/50] Batch 1300/1563                   Loss Discriminator: 0.342, loss Generator: 2.701
# Epoch [45/50] Batch 1400/1563                   Loss Discriminator: 0.170, loss Generator: 3.567
# Epoch [45/50] Batch 1500/1563                   Loss Discriminator: 0.166, loss Generator: 3.237
# Fretchet Distance:  236.70876274518346
# Epoch [46/50] Batch 0/1563                   Loss Discriminator: 0.350, loss Generator: 2.654
# Epoch [46/50] Batch 100/1563                   Loss Discriminator: 0.151, loss Generator: 3.577
# Epoch [46/50] Batch 200/1563                   Loss Discriminator: 0.119, loss Generator: 3.855
# Epoch [46/50] Batch 300/1563                   Loss Discriminator: 0.107, loss Generator: 3.725
# Epoch [46/50] Batch 400/1563                   Loss Discriminator: 0.337, loss Generator: 3.419
# Epoch [46/50] Batch 500/1563                   Loss Discriminator: 0.122, loss Generator: 3.596
# Epoch [46/50] Batch 600/1563                   Loss Discriminator: 0.193, loss Generator: 3.993
# Epoch [46/50] Batch 700/1563                   Loss Discriminator: 0.175, loss Generator: 3.075
# Epoch [46/50] Batch 800/1563                   Loss Discriminator: 0.212, loss Generator: 4.548
# Epoch [46/50] Batch 900/1563                   Loss Discriminator: 0.197, loss Generator: 3.603
# Epoch [46/50] Batch 1000/1563                   Loss Discriminator: 0.093, loss Generator: 3.533
# Epoch [46/50] Batch 1100/1563                   Loss Discriminator: 0.138, loss Generator: 3.960
# Epoch [46/50] Batch 1200/1563                   Loss Discriminator: 0.220, loss Generator: 2.946
# Epoch [46/50] Batch 1300/1563                   Loss Discriminator: 0.117, loss Generator: 4.074
# Epoch [46/50] Batch 1400/1563                   Loss Discriminator: 0.161, loss Generator: 3.297
# Epoch [46/50] Batch 1500/1563                   Loss Discriminator: 0.225, loss Generator: 3.458
# Fretchet Distance:  251.42346857950906
# Epoch [47/50] Batch 0/1563                   Loss Discriminator: 0.196, loss Generator: 4.065
# Epoch [47/50] Batch 100/1563                   Loss Discriminator: 0.088, loss Generator: 3.829
# Epoch [47/50] Batch 200/1563                   Loss Discriminator: 0.066, loss Generator: 4.452
# Epoch [47/50] Batch 300/1563                   Loss Discriminator: 0.146, loss Generator: 3.170
# Epoch [47/50] Batch 400/1563                   Loss Discriminator: 0.229, loss Generator: 3.160
# Epoch [47/50] Batch 500/1563                   Loss Discriminator: 0.189, loss Generator: 4.792
# Epoch [47/50] Batch 600/1563                   Loss Discriminator: 0.239, loss Generator: 3.291
# Epoch [47/50] Batch 700/1563                   Loss Discriminator: 0.168, loss Generator: 3.882
# Epoch [47/50] Batch 800/1563                   Loss Discriminator: 0.133, loss Generator: 3.316
# Epoch [47/50] Batch 900/1563                   Loss Discriminator: 0.104, loss Generator: 3.862
# Epoch [47/50] Batch 1000/1563                   Loss Discriminator: 0.093, loss Generator: 3.978
# Epoch [47/50] Batch 1100/1563                   Loss Discriminator: 0.297, loss Generator: 3.645
# Epoch [47/50] Batch 1200/1563                   Loss Discriminator: 0.197, loss Generator: 4.324
# Epoch [47/50] Batch 1300/1563                   Loss Discriminator: 0.135, loss Generator: 3.401
# Epoch [47/50] Batch 1400/1563                   Loss Discriminator: 0.188, loss Generator: 4.327
# Epoch [47/50] Batch 1500/1563                   Loss Discriminator: 0.249, loss Generator: 3.340
# Fretchet Distance:  257.93710667855606
# Epoch [48/50] Batch 0/1563                   Loss Discriminator: 0.076, loss Generator: 4.071
# Epoch [48/50] Batch 100/1563                   Loss Discriminator: 0.135, loss Generator: 4.318
# Epoch [48/50] Batch 200/1563                   Loss Discriminator: 0.186, loss Generator: 3.127
# Epoch [48/50] Batch 300/1563                   Loss Discriminator: 0.241, loss Generator: 3.023
# Epoch [48/50] Batch 400/1563                   Loss Discriminator: 0.114, loss Generator: 4.409
# Epoch [48/50] Batch 500/1563                   Loss Discriminator: 0.282, loss Generator: 4.615
# Epoch [48/50] Batch 600/1563                   Loss Discriminator: 0.470, loss Generator: 3.081
# Epoch [48/50] Batch 700/1563                   Loss Discriminator: 0.244, loss Generator: 4.098
# Epoch [48/50] Batch 800/1563                   Loss Discriminator: 0.227, loss Generator: 3.609
# Epoch [48/50] Batch 900/1563                   Loss Discriminator: 0.119, loss Generator: 4.023
# Epoch [48/50] Batch 1000/1563                   Loss Discriminator: 0.293, loss Generator: 4.264
# Epoch [48/50] Batch 1100/1563                   Loss Discriminator: 0.091, loss Generator: 3.928
# Epoch [48/50] Batch 1200/1563                   Loss Discriminator: 0.253, loss Generator: 2.767
# Epoch [48/50] Batch 1300/1563                   Loss Discriminator: 0.265, loss Generator: 3.028
# Epoch [48/50] Batch 1400/1563                   Loss Discriminator: 0.154, loss Generator: 3.414
# Epoch [48/50] Batch 1500/1563                   Loss Discriminator: 0.172, loss Generator: 4.073
# Fretchet Distance:  263.3374788933456
# Epoch [49/50] Batch 0/1563                   Loss Discriminator: 0.095, loss Generator: 4.148
# Epoch [49/50] Batch 100/1563                   Loss Discriminator: 0.210, loss Generator: 3.750
# Epoch [49/50] Batch 200/1563                   Loss Discriminator: 0.167, loss Generator: 4.306
# Epoch [49/50] Batch 300/1563                   Loss Discriminator: 0.118, loss Generator: 4.353
# Epoch [49/50] Batch 400/1563                   Loss Discriminator: 0.084, loss Generator: 4.066
# Epoch [49/50] Batch 500/1563                   Loss Discriminator: 0.232, loss Generator: 3.959
# Epoch [49/50] Batch 600/1563                   Loss Discriminator: 0.129, loss Generator: 3.892
# Epoch [49/50] Batch 700/1563                   Loss Discriminator: 0.131, loss Generator: 4.133
# Epoch [49/50] Batch 800/1563                   Loss Discriminator: 0.332, loss Generator: 5.066
# Epoch [49/50] Batch 900/1563                   Loss Discriminator: 0.177, loss Generator: 3.159
# Epoch [49/50] Batch 1000/1563                   Loss Discriminator: 0.226, loss Generator: 4.364
# Epoch [49/50] Batch 1100/1563                   Loss Discriminator: 0.123, loss Generator: 3.568
# Epoch [49/50] Batch 1200/1563                   Loss Discriminator: 0.220, loss Generator: 3.929
# Epoch [49/50] Batch 1300/1563                   Loss Discriminator: 0.093, loss Generator: 4.320
# Epoch [49/50] Batch 1400/1563                   Loss Discriminator: 0.151, loss Generator: 3.775
# Epoch [49/50] Batch 1500/1563                   Loss Discriminator: 0.189, loss Generator: 3.639
# Fretchet Distance:  266.5228722927626
# Epoch [50/50] Batch 0/1563                   Loss Discriminator: 0.156, loss Generator: 3.628
# Epoch [50/50] Batch 100/1563                   Loss Discriminator: 0.168, loss Generator: 3.738
# Epoch [50/50] Batch 200/1563                   Loss Discriminator: 0.194, loss Generator: 3.016
# Epoch [50/50] Batch 300/1563                   Loss Discriminator: 0.107, loss Generator: 4.493
# Epoch [50/50] Batch 400/1563                   Loss Discriminator: 0.246, loss Generator: 3.926
# Epoch [50/50] Batch 500/1563                   Loss Discriminator: 0.116, loss Generator: 3.881
# Epoch [50/50] Batch 600/1563                   Loss Discriminator: 0.201, loss Generator: 3.798
# Epoch [50/50] Batch 700/1563                   Loss Discriminator: 0.166, loss Generator: 3.681
# Epoch [50/50] Batch 800/1563                   Loss Discriminator: 0.166, loss Generator: 3.630
# Epoch [50/50] Batch 900/1563                   Loss Discriminator: 0.234, loss Generator: 3.729
# Epoch [50/50] Batch 1000/1563                   Loss Discriminator: 0.146, loss Generator: 4.305
# Epoch [50/50] Batch 1100/1563                   Loss Discriminator: 0.144, loss Generator: 4.354
# Epoch [50/50] Batch 1200/1563                   Loss Discriminator: 0.143, loss Generator: 3.799
# Epoch [50/50] Batch 1300/1563                   Loss Discriminator: 0.265, loss Generator: 3.927
# Epoch [50/50] Batch 1400/1563                   Loss Discriminator: 0.319, loss Generator: 3.516
# Epoch [50/50] Batch 1500/1563                   Loss Discriminator: 0.166, loss Generator: 4.194
# Fretchet Distance:  283.08978977690936
# elapsed time：2006.13 s.

# %%
plt.figure(figsize=(10,5))
plt.title("Generator and Discriminator Loss During Training")
plt.plot(GenLoss,label="Gen")
plt.plot(DiscLoss,label="Disc")
plt.xlabel("iterations")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8, 8))
plt.axis("off")
plt.imshow(np.transpose(utils.make_grid(real_batch[0].to(device)[:64], padding=5, normalize=True).cpu(), (1, 2, 0)))
plt.savefig('real_images.png')
plt.show()

# %%
plt.figure(figsize=(8, 8))
plt.axis("off")
plt.title("Generated Images")
plt.imshow(np.transpose(img_list[-1], (1, 2, 0)))
plt.savefig('DCGAN image.png')
plt.show()

# %%
dcgan = fretchet_distances

# %%
plt.plot(np.arange(1, 51), dcgan, label='FID')
plt.title('Frechet Distance for 50 epochs')
plt.xlabel('Epochs')  
plt.ylabel('FID')     
plt.legend()
plt.show()
